# %%
import sklearn

# %%
import pandas as pd

# %%
data=pd.read_csv('SpaceMissions.csv')

# %%
data.head()
# Out:
#   Company    Launch Date Launch Time       Launch Site  Temperature (° F)  \
# 0  SpaceX  24 March 2006       22:30  Marshall Islands               86.0
# 1  SpaceX  21 March 2007        1:10  Marshall Islands                NaN
# 2  SpaceX  3 August 2008        3:34  Marshall Islands                NaN
# 3  SpaceX  3 August 2008        3:34  Marshall Islands                NaN
# 4  SpaceX  3 August 2008        3:34  Marshall Islands                NaN
#
#    Wind speed (MPH)  Humidity (%) Vehicle Type  Liftoff Thrust (kN)  \
# 0               9.0          74.0     Falcon 1                  343
# 1               NaN           NaN     Falcon 1                  343
# 2               NaN           NaN     Falcon 1                  343
# 3               NaN           NaN     Falcon 1                  343
# 4               NaN           NaN     Falcon 1                  343
#
#    Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)  \
# 0                    470              22.25                   1.5
# 1                    470              22.25                   1.5
# 2                    470              22.25                   1.5
# 3                    470              22.25                   1.5
# 4                    470              22.25                   1.5
#
#          Payload Name             Payload Type Payload Mass (kg)  \
# 0         FalconSAT-2       Research Satellite              19.5
# 1             DemoSat           Mass simulator               NaN
# 2         Trailblazer  Communication Satellite               NaN
# 3  PRESat, NanoSail-D      Research Satellites                 8
# 4           Explorers            Human Remains               NaN
#
#      Payload Orbit Mission Status                 Failure Reason
# 0  Low Earth Orbit        Failure      Engine Fire During Launch
# 1  Low Earth Orbit        Failure  Engine Shutdown During Launch
# 2  Low Earth Orbit        Failure        Collision During Launch
# 3  Low Earth Orbit        Failure        Collision During Launch
# 4  Low Earth Orbit        Failure        Collision During Launch

# %%
data.columns
# Out:
# Index(['Company', 'Launch Date', 'Launch Time', 'Launch Site',
#        'Temperature (° F)', 'Wind speed (MPH)', 'Humidity (%)', 'Vehicle Type',
#        'Liftoff Thrust (kN)', 'Payload to Orbit (kg)', 'Rocket Height (m)',
#        'Fairing Diameter (m)', 'Payload Name', 'Payload Type',
#        'Payload Mass (kg)', 'Payload Orbit', 'Mission Status',
#        'Failure Reason'],
#       dtype='object')

# %%
year_list=[]
for i in  data["Launch Date"]:
    word=i
    year_list.append(word[-4:])
print(len(year_list))
print(len(data['Launch Date']))
# Out:
# 150
# 150

# %%
data['Launch Date']=year_list

# %%
data.sort_values(by='Launch Date',inplace=True)

# %%
data
# Out:
#           Company Launch Date Launch Time           Launch Site  \
# 20   US Air Force        1964       15:00        Cape Canaveral
# 19   US Air Force        1965       17:23        Cape Canaveral
# 18   US Air Force        1967         NaN           Vandenberg
# 17   US Air Force        1967       16:19           Vandenberg
# 16   US Air Force        1972       15:30           Vandenberg
# ..            ...         ...         ...                   ...
# 113        SpaceX        2020        2:19        Cape Canaveral
# 114        SpaceX        2020       15:30  Kennedy Space Center
# 115        SpaceX        2020       14:06        Cape Canaveral
# 116        SpaceX        2020       15:05        Cape Canaveral
# 117        SpaceX        2020        4:50        Cape Canaveral
#
#      Temperature (° F)  Wind speed (MPH)  Humidity (%)      Vehicle Type  \
# 20                 NaN               NaN           NaN        Titan IIIA
# 19                 NaN               NaN           NaN        Titan IIIC
# 18                56.0              12.0          75.0        Titan IIIB
# 17                60.0              15.0          80.0        Titan IIIB
# 16                64.0              20.0          46.0    Titan III(24)B
# ..                 ...               ...           ...               ...
# 113               48.0               5.0          93.0  Falcon 9 Block 5
# 114               81.0               8.0          54.0  Falcon 9 Block 5
# 115               72.0               8.0          68.0  Falcon 9 Block 5
# 116               77.0               9.0          74.0  Falcon 9 Block 5
# 117               55.0              22.0          55.0  Falcon 9 Block 5
#
#      Liftoff Thrust (kN)  Payload to Orbit (kg)  Rocket Height (m)  \
# 20                  1936                   3100               42.0
# 19                 13642                  13100               42.0
# 18                  2300                   3300               45.0
# 17                  2300                   3300               45.0
# 16                  2410                   4000               50.0
# ..                   ...                    ...                ...
# 113                 7607                  22800               70.0
# 114                 7607                  22800               70.0
# 115                 7607                  22800               70.0
# 116                 7607                  22800               70.0
# 117                 7607                  22800               70.0
#
#      Fairing Diameter (m)                     Payload Name  \
# 20                   3.00                      Transtage 1
# 19                   3.00                            LCS-2
# 18                   1.52                KH-8 Gambit no.05
# 17                   1.52                KH-8 Gambit no.06
# 16                   3.00                      KH-8 no. 35
# ..                    ...                              ...
# 113                  5.20                   Starlink V1 L2
# 114                  5.20  Crew Dragon Inflight Abort Test
# 115                  5.20                   Starlink V1 L3
# 116                  5.20                   Starlink V1 L4
# 117                  5.20                           CRS-20
#
#                   Payload Type Payload Mass (kg)    Payload Orbit  \
# 20                        None                 0  Low Earth Orbit
# 19          Research Satellite               NaN  Low Earth Orbit
# 18   Reconnaissance Satellites              3000      Polar Orbit
# 17   Reconnaissance Satellites              3000      Polar Orbit
# 16   Reconnaissance Satellites              3000  Low Earth Orbit
# ..                         ...               ...              ...
# 113    Communication Satellite             15600  Low Earth Orbit
# 114       in-flight abort test              6350       Suborbital
# 115    Communication Satellite             15600  Low Earth Orbit
# 116    Communication Satellite             15600  Low Earth Orbit
# 117     Space Station Supplies              2500  Low Earth Orbit
#
#     Mission Status                                     Failure Reason
# 20         Failure                    Transtage failed to pressurize.
# 19         Failure  The Transtage disintegrated causing a launch f...
# 18         Failure  A loss of thrust in the second stage means the...
# 17         Failure  A problem with the second stage protective ski...
# 16         Failure                       Agena pressurization failure
# ..             ...                                                ...
# 113        Success                                                NaN
# 114        Success                                                NaN
# 115        Success                                                NaN
# 116        Success                                                NaN
# 117        Success                                                NaN
#
# [150 rows x 18 columns]

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
data['Mission Status']=enc.fit_transform(data["Mission Status"])

# %%
import seaborn as sns
sns.set_theme()
sns.histplot(x='Mission Status',data=data)
# Out:
# <AxesSubplot:xlabel='Mission Status', ylabel='Count'>

# %%
for i in data["Launch Date"]:
  i=int(i)

# %%
data["Launch Date"].value_counts()
# Out:
# 2018    21
# 2017    18
# 2019    14
# 1999    12
# 2016    10
# 2015     8
# 2000     7
# 2001     7
# 2014     6
# 2002     5
# 2020     5
# 2008     4
# 1998     4
# 2012     3
# 2013     3
# 1996     2
# 2010     2
# 1997     2
# 2003     2
# 1967     2
# 1965     1
# 1980     1
# 2009     1
# 1995     1
# 2007     1
# 2006     1
# 1972     1
# 1994     1
# 1964     1
# 2004     1
# 1973     1
# 1993     1
# 1982     1
# Name: Launch Date, dtype: int64

# %%
sns.set(rc={'figure.figsize':(45,8)})
sns.histplot(y='Company',hue='Mission Status',data=data)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Company'>

# %%
sns.set(rc={'figure.figsize':(45,8)})
sns.histplot(x='Launch Date',data=data,hue='Company')
# Out:
# <AxesSubplot:xlabel='Launch Date', ylabel='Count'>

# %%
data['Vehicle Type'].value_counts()
# Out:
# Falcon 9 Block 5               26
# Falcon 9 Full Thrust (v1.2)    18
# Falcon 9 (v1.1)                16
# Falcon 9 Block 4               12
# Delta II 7925                  10
# Falcon 9 Block 3                8
# Falcon 1                        7
# Falcon 9 (v1.0)                 6
# Delta II 7920-10C               5
# Delta II 7320-10C               4
# Delta II 7420-10C               4
# Delta III 8930                  3
# Delta II 7425                   3
# VLS-1                           3
# Falcon Heavy                    3
# Ariane 1                        2
# Delta II 7920-10                2
# Titan IIIB                      2
# Delta II 7326                   2
# Titan IIIC                      2
# Titan III(24)B                  2
# Ariane 5 ECA                    1
# Titan IIIA                      1
# Vega                            1
# Delta II 7425-10C               1
# Titan II(23)G                   1
# Ariane 42P                      1
# Delta IV Medium+ (4,2)          1
# Ariane 5 G                      1
# Delta IV Heavy                  1
# Delta II 7426                   1
# Name: Vehicle Type, dtype: int64

# %%
data['Company'].value_counts()
# Out:
# SpaceX                    96
# Boeing                    37
# US Air Force               7
# Arianespace                4
# Brazilian Space Agency     3
# European Space Agency      2
# Martin Marietta            1
# Name: Company, dtype: int64

# %%
data['Company']=enc.fit_transform(data['Company'])

# %%
print(data[113:118])
# Out:
#     Company Launch Date Launch Time     Launch Site  Temperature (° F)  \
# 82        5        2018       14:17     Vandenberg                56.0
# 93        5        2018        5:18  Cape Canaveral               80.0
# 80        5        2018       21:25  Cape Canaveral               52.0
# 79        5        2018        1:00  Cape Canaveral               64.0
# 86        5        2018       22:51  Cape Canaveral               69.0
#
#     Wind speed (MPH)  Humidity (%)      Vehicle Type  Liftoff Thrust (kN)  \
# 82              23.0          50.0  Falcon 9 Block 3                 6804
# 93               8.0          79.0  Falcon 9 Block 5                 7607
# 80               3.0          86.0  Falcon 9 Block 3                 6804
# 79              12.0          70.0  Falcon 9 Block 4                 6804
# 86               9.0          75.0  Falcon 9 Block 4                 6804
#
#     Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)  \
# 82                  22800               70.0                   5.2
# 93                   8300               70.0                   5.2
# 80                   8300               70.0                   5.2
# 79                  22800               70.0                   5.2
# 86                   8300               70.0                   5.2
#
#                                     Payload Name  \
# 82                            PAZ / Tintin A & B
# 93                        Merah Putih (Telkom-4)
# 80                             GovSat-1 / SES-16
# 79                                          Zuma
# 86  Transiting Exoplanet Survey Satellite (TESS)
#
#                                          Payload Type Payload Mass (kg)  \
# 82         Spain's spy satellite / internet satellite              2141
# 93                            Communication Satellite              5800
# 80  Governmental and institutional security user n...              4230
# 79                                         Classified        Classified
# 86                                       Star monitor               362
#
#                    Payload Orbit  Mission Status Failure Reason
# 82         Sun-Synchronous Orbit               1            NaN
# 93  Geostationary Transfer Orbit               1            NaN
# 80  Geostationary Transfer Orbit               1            NaN
# 79               Low Earth Orbit               1            NaN
# 86              High Earth Orbit               1            NaN

# %%
data['Company'].unique()
# Out:
# array([6, 3, 4, 0, 1, 2, 5])

# %%
data=data.drop("Launch Site",axis=1)

# %%
data['Temperature (° F)'].unique()
# Out:
# array([nan, 56., 60., 64., 50., 62., 84., 90., 55., 82., 72., 77., 58.,
#        88., 79., 68., 70., 57., 47., 75., 45., 78., 87., 71., 81., 80.,
#        51., 59., 76., 83., 86., 61., 74., 69., 73., 93., 63., 65., 67.,
#        89., 37., 54., 91., 53., 52., 48.])

# %%
temp_mean=data['Temperature (° F)'].mean()

# %%
type(data['Temperature (° F)'][2])
# Out:
# numpy.float64

# %%
import numpy as np

# %%
for i in range (0,len(data["Temperature (° F)"])):
        if np.isnan(data["Temperature (° F)"][i]):
           data["Temperature (° F)"][i]=temp_mean
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data["Temperature (° F)"].unique()
# Out:
# array([70.44117647, 56.        , 60.        , 64.        , 50.        ,
#        62.        , 84.        , 90.        , 55.        , 82.        ,
#        72.        , 77.        , 58.        , 88.        , 79.        ,
#        68.        , 70.        , 57.        , 47.        , 75.        ,
#        45.        , 78.        , 87.        , 71.        , 81.        ,
#        80.        , 51.        , 59.        , 76.        , 83.        ,
#        86.        , 61.        , 74.        , 69.        , 73.        ,
#        93.        , 63.        , 65.        , 67.        , 89.        ,
#        37.        , 54.        , 91.        , 53.        , 52.        ,
#        48.        ])

# %%
Wind_mean=data['Wind speed (MPH)'].mean()

# %%
for i in range (0,len(data["Wind speed (MPH)"])):
        if np.isnan(data["Wind speed (MPH)"][i]):
           data["Wind speed (MPH)"][i]=Wind_mean
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data
# Out:
#      Company Launch Date Launch Time  Temperature (° F)  Wind speed (MPH)  \
# 20         6        1964       15:00          70.441176          8.007353
# 19         6        1965       17:23          70.441176          8.007353
# 18         6        1967         NaN          56.000000         12.000000
# 17         6        1967       16:19          60.000000         15.000000
# 16         6        1972       15:30          64.000000         20.000000
# ..       ...         ...         ...                ...               ...
# 113        5        2020        2:19          48.000000          5.000000
# 114        5        2020       15:30          81.000000          8.000000
# 115        5        2020       14:06          72.000000          8.000000
# 116        5        2020       15:05          77.000000          9.000000
# 117        5        2020        4:50          55.000000         22.000000
#
#      Humidity (%)      Vehicle Type  Liftoff Thrust (kN)  \
# 20            NaN        Titan IIIA                 1936
# 19            NaN        Titan IIIC                13642
# 18           75.0        Titan IIIB                 2300
# 17           80.0        Titan IIIB                 2300
# 16           46.0    Titan III(24)B                 2410
# ..            ...               ...                  ...
# 113          93.0  Falcon 9 Block 5                 7607
# 114          54.0  Falcon 9 Block 5                 7607
# 115          68.0  Falcon 9 Block 5                 7607
# 116          74.0  Falcon 9 Block 5                 7607
# 117          55.0  Falcon 9 Block 5                 7607
#
#      Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)  \
# 20                    3100               42.0                  3.00
# 19                   13100               42.0                  3.00
# 18                    3300               45.0                  1.52
# 17                    3300               45.0                  1.52
# 16                    4000               50.0                  3.00
# ..                     ...                ...                   ...
# 113                  22800               70.0                  5.20
# 114                  22800               70.0                  5.20
# 115                  22800               70.0                  5.20
# 116                  22800               70.0                  5.20
# 117                  22800               70.0                  5.20
#
#                         Payload Name               Payload Type  \
# 20                       Transtage 1                       None
# 19                             LCS-2         Research Satellite
# 18                 KH-8 Gambit no.05  Reconnaissance Satellites
# 17                 KH-8 Gambit no.06  Reconnaissance Satellites
# 16                       KH-8 no. 35  Reconnaissance Satellites
# ..                               ...                        ...
# 113                   Starlink V1 L2    Communication Satellite
# 114  Crew Dragon Inflight Abort Test       in-flight abort test
# 115                   Starlink V1 L3    Communication Satellite
# 116                   Starlink V1 L4    Communication Satellite
# 117                           CRS-20     Space Station Supplies
#
#     Payload Mass (kg)    Payload Orbit  Mission Status  \
# 20                  0  Low Earth Orbit               0
# 19                NaN  Low Earth Orbit               0
# 18               3000      Polar Orbit               0
# 17               3000      Polar Orbit               0
# 16               3000  Low Earth Orbit               0
# ..                ...              ...             ...
# 113             15600  Low Earth Orbit               1
# 114              6350       Suborbital               1
# 115             15600  Low Earth Orbit               1
# 116             15600  Low Earth Orbit               1
# 117              2500  Low Earth Orbit               1
#
#                                         Failure Reason
# 20                     Transtage failed to pressurize.
# 19   The Transtage disintegrated causing a launch f...
# 18   A loss of thrust in the second stage means the...
# 17   A problem with the second stage protective ski...
# 16                        Agena pressurization failure
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
# [150 rows x 17 columns]

# %%
Hum_mean=data['Humidity (%)'].mean()

# %%
for i in range (0,len(data["Humidity (%)"])):
        if np.isnan(data["Humidity (%)"][i]):
           data["Humidity (%)"][i]=Hum_mean
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data
# Out:
#      Company Launch Date Launch Time  Temperature (° F)  Wind speed (MPH)  \
# 20         6        1964       15:00          70.441176          8.007353
# 19         6        1965       17:23          70.441176          8.007353
# 18         6        1967         NaN          56.000000         12.000000
# 17         6        1967       16:19          60.000000         15.000000
# 16         6        1972       15:30          64.000000         20.000000
# ..       ...         ...         ...                ...               ...
# 113        5        2020        2:19          48.000000          5.000000
# 114        5        2020       15:30          81.000000          8.000000
# 115        5        2020       14:06          72.000000          8.000000
# 116        5        2020       15:05          77.000000          9.000000
# 117        5        2020        4:50          55.000000         22.000000
#
#      Humidity (%)      Vehicle Type  Liftoff Thrust (kN)  \
# 20      76.066176        Titan IIIA                 1936
# 19      76.066176        Titan IIIC                13642
# 18      75.000000        Titan IIIB                 2300
# 17      80.000000        Titan IIIB                 2300
# 16      46.000000    Titan III(24)B                 2410
# ..            ...               ...                  ...
# 113     93.000000  Falcon 9 Block 5                 7607
# 114     54.000000  Falcon 9 Block 5                 7607
# 115     68.000000  Falcon 9 Block 5                 7607
# 116     74.000000  Falcon 9 Block 5                 7607
# 117     55.000000  Falcon 9 Block 5                 7607
#
#      Payload to Orbit (kg)  Rocket Height (m)  Fairing Diameter (m)  \
# 20                    3100               42.0                  3.00
# 19                   13100               42.0                  3.00
# 18                    3300               45.0                  1.52
# 17                    3300               45.0                  1.52
# 16                    4000               50.0                  3.00
# ..                     ...                ...                   ...
# 113                  22800               70.0                  5.20
# 114                  22800               70.0                  5.20
# 115                  22800               70.0                  5.20
# 116                  22800               70.0                  5.20
# 117                  22800               70.0                  5.20
#
#                         Payload Name               Payload Type  \
# 20                       Transtage 1                       None
# 19                             LCS-2         Research Satellite
# 18                 KH-8 Gambit no.05  Reconnaissance Satellites
# 17                 KH-8 Gambit no.06  Reconnaissance Satellites
# 16                       KH-8 no. 35  Reconnaissance Satellites
# ..                               ...                        ...
# 113                   Starlink V1 L2    Communication Satellite
# 114  Crew Dragon Inflight Abort Test       in-flight abort test
# 115                   Starlink V1 L3    Communication Satellite
# 116                   Starlink V1 L4    Communication Satellite
# 117                           CRS-20     Space Station Supplies
#
#     Payload Mass (kg)    Payload Orbit  Mission Status  \
# 20                  0  Low Earth Orbit               0
# 19                NaN  Low Earth Orbit               0
# 18               3000      Polar Orbit               0
# 17               3000      Polar Orbit               0
# 16               3000  Low Earth Orbit               0
# ..                ...              ...             ...
# 113             15600  Low Earth Orbit               1
# 114              6350       Suborbital               1
# 115             15600  Low Earth Orbit               1
# 116             15600  Low Earth Orbit               1
# 117              2500  Low Earth Orbit               1
#
#                                         Failure Reason
# 20                     Transtage failed to pressurize.
# 19   The Transtage disintegrated causing a launch f...
# 18   A loss of thrust in the second stage means the...
# 17   A problem with the second stage protective ski...
# 16                        Agena pressurization failure
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
# [150 rows x 17 columns]

# %%
data["Vehicle Type"].unique()
# Out:
# array(['Titan IIIA', 'Titan IIIC', 'Titan IIIB', 'Titan III(24)B',
#        'Ariane 1', 'Titan II(23)G', 'Ariane 42P', 'Delta II 7925',
#        'Ariane 5 G', 'VLS-1', 'Delta II 7920-10C', 'Delta III 8930',
#        'Delta II 7425', 'Delta II 7920-10', 'Delta II 7420-10C',
#        'Delta II 7320-10C', 'Delta II 7426', 'Delta II 7326',
#        'Delta II 7425-10C', 'Delta IV Medium+ (4,2)', 'Ariane 5 ECA',
#        'Delta IV Heavy', 'Falcon 1', 'Falcon 9 (v1.0)', 'Falcon 9 (v1.1)',
#        'Falcon 9 Full Thrust (v1.2)', 'Falcon 9 Block 4',
#        'Falcon 9 Block 3', 'Falcon 9 Block 5', 'Falcon Heavy', 'Vega'],
#       dtype=object)

# %%
data["Vehicle Type"].value_counts()
# Out:
# Falcon 9 Block 5               26
# Falcon 9 Full Thrust (v1.2)    18
# Falcon 9 (v1.1)                16
# Falcon 9 Block 4               12
# Delta II 7925                  10
# Falcon 9 Block 3                8
# Falcon 1                        7
# Falcon 9 (v1.0)                 6
# Delta II 7920-10C               5
# Delta II 7320-10C               4
# Delta II 7420-10C               4
# Delta III 8930                  3
# Delta II 7425                   3
# VLS-1                           3
# Falcon Heavy                    3
# Ariane 1                        2
# Delta II 7920-10                2
# Titan IIIB                      2
# Delta II 7326                   2
# Titan IIIC                      2
# Titan III(24)B                  2
# Ariane 5 ECA                    1
# Titan IIIA                      1
# Vega                            1
# Delta II 7425-10C               1
# Titan II(23)G                   1
# Ariane 42P                      1
# Delta IV Medium+ (4,2)          1
# Ariane 5 G                      1
# Delta IV Heavy                  1
# Delta II 7426                   1
# Name: Vehicle Type, dtype: int64

# %%
others=['VLS-1',
'Delta III 8930',
'Delta II 7425',
'Falcon Heavy',
'Titan IIIC',                    
'Titan IIIB',                      
'Delta II 7920-10'                
'Ariane 1',                        
'Delta II 7326',                   
'Titan III(24)B',                  
'Delta II 7426',                   
'Delta IV Heavy',                  
'Titan IIIA',                      
'Vega'                            
'Ariane 5 G',                      
'Delta II 7425-10C',               
'Ariane 42P',                      
'Ariane 5 ECA',                    
'Delta IV Medium+ (4,2)',          
'Titan II(23)G'  ]

# %%
for i in range (0,len(data['Vehicle Type'])):
    if(data["Vehicle Type"][i] in others):
        data['Vehicle Type'][i]='Other'
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['Vehicle Type'].value_counts()
# Out:
# Other                          28
# Falcon 9 Block 5               26
# Falcon 9 Full Thrust (v1.2)    18
# Falcon 9 (v1.1)                16
# Falcon 9 Block 4               12
# Delta II 7925                  10
# Falcon 9 Block 3                8
# Falcon 1                        7
# Falcon 9 (v1.0)                 6
# Delta II 7920-10C               5
# Delta II 7320-10C               4
# Delta II 7420-10C               4
# Ariane 1                        2
# Delta II 7920-10                2
# Vega                            1
# Ariane 5 G                      1
# Name: Vehicle Type, dtype: int64

# %%
for i in range(0,len(data['Vehicle Type'])):
    if(data['Vehicle Type'][i]=='Ariane 5 G' or data['Vehicle Type'][i]=='Vega' ):
        data['Vehicle Type'][i]='Other'
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['Vehicle Type'].value_counts()
# Out:
# Other                          30
# Falcon 9 Block 5               26
# Falcon 9 Full Thrust (v1.2)    18
# Falcon 9 (v1.1)                16
# Falcon 9 Block 4               12
# Delta II 7925                  10
# Falcon 9 Block 3                8
# Falcon 1                        7
# Falcon 9 (v1.0)                 6
# Delta II 7920-10C               5
# Delta II 7320-10C               4
# Delta II 7420-10C               4
# Ariane 1                        2
# Delta II 7920-10                2
# Name: Vehicle Type, dtype: int64

# %%
for i in range(0,len(data['Vehicle Type'])):
    if(data['Vehicle Type'][i]=='Ariane 1' or data['Vehicle Type'][i]=='Delta II 7920-10' ):
        data['Vehicle Type'][i]='Other'
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['Vehicle Type'].value_counts()
# Out:
# Other                          34
# Falcon 9 Block 5               26
# Falcon 9 Full Thrust (v1.2)    18
# Falcon 9 (v1.1)                16
# Falcon 9 Block 4               12
# Delta II 7925                  10
# Falcon 9 Block 3                8
# Falcon 1                        7
# Falcon 9 (v1.0)                 6
# Delta II 7920-10C               5
# Delta II 7320-10C               4
# Delta II 7420-10C               4
# Name: Vehicle Type, dtype: int64

# %%
sns.set(rc={'figure.figsize':(45,8)})
sns.histplot(x='Launch Date',data=data,hue='Vehicle Type')
# Out:
# <AxesSubplot:xlabel='Launch Date', ylabel='Count'>

# %%
sns.color_palette('husl',9)
sns.set(rc={'figure.figsize':(45,8)})
sns.histplot(x='Payload to Orbit (kg)',y='Launch Date',data=data,hue='Vehicle Type')
# Out:
# <AxesSubplot:xlabel='Payload to Orbit (kg)', ylabel='Launch Date'>

# %%
data['Vehicle Type']=enc.fit_transform(data['Vehicle Type'])

# %% [markdown]
# #### sns.color_palette()
# sns.set(rc={'figure.figsize':(45,8)})
# sns.histplot(x='Launch Date',data=data,hue='Vehicle Type')

# %%
data['Payload Name'].unique()
# Out:
# array(['Transtage 1', 'LCS-2', 'KH-8 Gambit no.05', 'KH-8 Gambit no.06',
#        'KH-8 no. 35', 'KH-8 no. 39',
#        'CAT-2 / Amsat P3A / Firewheel Subsat', 'MARCES-B / Sirio-2',
#        'Landsat 6', 'Panamsat-3', 'Koreasat 1', 'Cluster', 'IDCSP GGTS-2',
#        'SCD-2A', 'GPS IIR-1', 'MS-11', 'Galaxy 10',
#        'Mars Climate Orbiter', 'BONUM-1', 'Landsat 7',
#        'USA-145 (GPS IIR-3)', 'Globalstar 5', 'Globalstar 4',
#        'Globalstar 6', 'ARGOS (P91-1 ARGOS)', 'Globalstar 3', 'FUSE',
#        'Stardust', 'Orion 3', 'Mars Polar Lander', 'SACI-2',
#        'Globalstar 7', 'IMAGE', 'USA-150 (GPS IIR-4)',
#        'USA-151 (GPS IIR-5)', 'USA-154 (GPS IIR-6)', 'EO-1', 'DM F3',
#        'USA-156 (GPS IIR-7)', 'Mars Odyssey', 'Genesis', 'QuickBird',
#        'Jason-1 / TIMED', 'WMAP', 'GeoLITE', 'Eutelsat W5',
#        'Iridium IS-1', 'Aqua', 'CONTOUR', 'Hot Bird 7, STENTOR',
#        'SATEC, UNOSAT', 'ICESat', 'DemoSat / 3CS-1 & 2', 'FalconSAT-2',
#        'DemoSat', 'Trailblazer', 'RatSat (DemoSat)', 'Explorers',
#        'PRESat, NanoSail-D', 'RazakSAT', 'SpaceX CRS (Dragon C1)',
#        'Dragon Spacecraft Qualification Unit', 'Orbcomm-OG2',
#        'SpaceX CRS-1', 'SpaceX CRS (Dragon C2+)', 'SpaceX CRS-2',
#        'CASSIOPE', 'SES-8', 'Thaicom 6', 'SpaceX CRS-3', 'AsiaSat 6',
#        'SpaceX CRS-4', 'OG2 Mission 1 (6 OG2 Satellites)', 'AsiaSat 8',
#        'OG2 Mission 2 (11 OG2 Satellites)', 'SpaceX CRS-7',
#        'SpaceX CRS-5', 'DSCOVR', 'ABS-3A',
#        'Eutelsat 115 West B (Satmex 7)', 'SpaceX CRS-6',
#        'TurkmenAlem 52E/MonacoSAT', 'SpaceX CRS-8', 'Amos-6', 'JCSAT-16',
#        'SpaceX CRS-9', 'Eutelsat 117 West B (Satmex 9)', 'ABS-2A',
#        'Thaicom 8', 'JCSAT-14', 'Jason-3', 'SES-9', 'Iridium-3', 'OTV-5',
#        'Iridium-4', 'CRS-13', 'Koreasat 5A', 'SES-11 / EchoStar 105',
#        'Formosat-5', 'CRS-12', 'Iridium-2', 'Intelsat 35e',
#        'SpaceX CRS-11', 'Inmarsat-5 F4', 'NROL-76', 'SpaceX SES-10',
#        'SpaceX Echostar 23', 'SpaceX CRS-10', 'Iridium NEXT 1-10',
#        'BulgariaSat-1', 'Hispasat 30W-6', 'CRS-14', 'Iridium-5',
#        'PAZ / Tintin A & B', 'Merah Putih (Telkom-4)',
#        'GovSat-1 / SES-16', 'Zuma',
#        'Transiting Exoplanet Survey Satellite (TESS)',
#        "Elon Musk's Tesla Roadster", 'Iridium-7', 'Bangabandhu-1',
#        'SES-12', 'CRS-15', 'Telstar 18V / APStar 5C', 'SAOCOM 1A',
#        "Es'hail 2", 'Spaceflight SSO-A', 'CRS-16', 'GPS III SV01',
#        'Telstar 19V', 'Iridium-6 / GRACE-FO', 'Iridium-8', 'Falcon Eye 1',
#        'SpaceX Demo-1', 'ArabSat 6A', 'CRS-17', 'Starlink v0.9', 'STP-2',
#        'CRS-18', 'AMOS-17', 'Starlink V1 L1', 'CRS-19',
#        'JCSAT-18 / Kacific-1', 'RADARSAT Constellation',
#        'Nusantara Satu / Beresheet / AFRL S5', 'Starlink V1 L2',
#        'Crew Dragon Inflight Abort Test', 'Starlink V1 L3',
#        'Starlink V1 L4', 'CRS-20'], dtype=object)

# %%
data["Payload Type"].unique()
# Out:
# array(['None', 'Research Satellite', 'Reconnaissance Satellites',
#        'Communication Satellite', 'Enhanced Thematic Mapper',
#        'European Space Agency spacecraft',
#        'Gravity Gradient Test Satellite', 'Research Satellites',
#        'Global Positioning System', 'Robotic space probe',
#        'Space-based Telescope', 'Robotic spacecraft lander',
#        'Earth Observation Satellite', 'Test Satellite',
#        'Orbiting Robotic Spacecraft',
#        'Solar wind particles sample-return probe',
#        'Microwave Anisotropy Probe', 'Space Probe', 'Mass simulator', nan,
#        'Human Remains', 'Weather Satellite', 'Space Station Supplies',
#        'Communication/Research Satellite', 'reusable uncrewed spacecraft',
#        'Direct-to-Home (DTH) broadcast, broadband, and backhaul services',
#        'Earth observation satellite',
#        'high-speed mobile broadband service', 'Classified',
#        "Spain's spy satellite / internet satellite",
#        'Governmental and institutional security user needs satellite',
#        'Star monitor',
#        'Tesla carrying mannequin Starman – sporting SpaceX spacesuit',
#        'Direct-to-Home Television Services', 'GPS III satellites',
#        'Communication Satellite / Research satellite',
#        'optical reconnaissance system',
#        'Uncrewed Test Commercial Crew program',
#        'Earth observation satellites',
#        'Communication Satellite / Moon lander / Reseach Satellite',
#        'in-flight abort test'], dtype=object)

# %%
data["Payload Type"].value_counts()
# Out:
# Communication Satellite                                             61
# Space Station Supplies                                              22
# Research Satellite                                                  10
# Global Positioning System                                            6
# Earth Observation Satellite                                          4
# Research Satellites                                                  4
# Reconnaissance Satellites                                            4
# Weather Satellite                                                    3
# Robotic space probe                                                  2
# Classified                                                           2
# Enhanced Thematic Mapper                                             1
# Earth observation satellite                                          1
# Star monitor                                                         1
# Robotic spacecraft lander                                            1
# Communication/Research Satellite                                     1
# reusable uncrewed spacecraft                                         1
# Uncrewed Test Commercial Crew program                                1
# Communication Satellite / Moon lander / Reseach Satellite            1
# Direct-to-Home (DTH) broadcast, broadband, and backhaul services     1
# Microwave Anisotropy Probe                                           1
# Solar wind particles sample-return probe                             1
# Orbiting Robotic Spacecraft                                          1
# Earth observation satellites                                         1
# Direct-to-Home Television Services                                   1
# Space Probe                                                          1
# Mass simulator                                                       1
# in-flight abort test                                                 1
# Test Satellite                                                       1
# Tesla carrying mannequin Starman – sporting SpaceX spacesuit         1
# Communication Satellite / Research satellite                         1
# GPS III satellites                                                   1
# high-speed mobile broadband service                                  1
# optical reconnaissance system                                        1
# Gravity Gradient Test Satellite                                      1
# European Space Agency spacecraft                                     1
# None                                                                 1
# Governmental and institutional security user needs satellite         1
# Human Remains                                                        1
# Spain's spy satellite / internet satellite                           1
# Space-based Telescope                                                1
# Name: Payload Type, dtype: int64

# %%
others2=['Weather Satellite',                                                   
'Robotic space probe',                                                  
'Classified',                                                           
'Star monitor',                                                         
'GPS III satellites',                                                   
'Human Remains',                                                        
"Spain's spy satellite / internet satellite",                           
'Communication Satellite / Moon lander / Reseach Satellite',            
'high-speed mobile broadband service',                                  
'Orbiting Robotic Spacecraft',                                          
'reusable uncrewed spacecraft',                                         
'Space Probe',                                                         
'Enhanced Thematic Mapper',                                             
'in-flight abort test',                                                 
'Governmental and institutional security user needs satellite',         
'European Space Agency spacecraft',                                     
'Uncrewed Test Commercial Crew program',                                
'Gravity Gradient Test Satellite',                                      
'None' ,                                                                
'Test Satellite',                                                       
'Communication/Research Satellite',                                     
'Solar wind particles sample-return probe',                            
'Microwave Anisotropy Probe',                                           
'Earth observation satellite',                                          
'Direct-to-Home (DTH) broadcast, broadband, and backhaul services',     
'Robotic spacecraft lander',                                            
'Earth observation satellites',                                         
'Direct-to-Home Television Services',                                   
'Space-based Telescope',                                                
'optical reconnaissance system',                                        
'Mass simulator',                                                       
'Communication Satellite / Research satellite',                         
'Tesla carrying mannequin Starman – sporting SpaceX spacesuit'        ]

# %%
for i in range (0,len(data["Payload Type"])):
    if(data["Payload Type"][i] in others2):
        data["Payload Type"][i]='Other'
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['Payload Type'].value_counts()
# Out:
# Communication Satellite        61
# Other                          37
# Space Station Supplies         22
# Research Satellite             10
# Global Positioning System       6
# Research Satellites             4
# Reconnaissance Satellites       4
# Earth Observation Satellite     4
# Name: Payload Type, dtype: int64

# %%
data["Payload Type"]=enc.fit_transform(data["Payload Type"])

# %%
sns.color_palette()
sns.histplot(x='Payload Orbit',hue='Company',data=data)
# Out:
# <AxesSubplot:xlabel='Payload Orbit', ylabel='Count'>

# %%
data["Payload Orbit"].value_counts()
# Out:
# Low Earth Orbit                 63
# Geostationary Transfer Orbit    45
# Polar Orbit                     12
# Sun-Synchronous Orbit            9
# Medium Earth Orbit               9
# Heliocentric Orbit               6
# High Earth Orbit                 2
# Sun/Earth Orbit                  1
# Earth-Moon L2                    1
# Suborbital                       1
# Mars Orbit                       1
# Name: Payload Orbit, dtype: int64

# %%
sns.set(rc={'figure.figsize':(45,8)})
sns.histplot(x='Payload Orbit',hue='Company',data=data)
# Out:
# <AxesSubplot:xlabel='Payload Orbit', ylabel='Count'>

# %%
sns.histplot(x='Payload Orbit',hue='Mission Status',data=data)
# Out:
# <AxesSubplot:xlabel='Payload Orbit', ylabel='Count'>

# %%
sns.set(rc={'figure.figsize':(45,8)})
sns.histplot(x='Vehicle Type',y='Launch Date',hue='Company',data=data)
# Out:
# <AxesSubplot:xlabel='Vehicle Type', ylabel='Launch Date'>

# %%
data["Payload Orbit"]=enc.fit_transform(data["Payload Orbit"])

# %%
sns.barplot(y='Payload to Orbit (kg)',x='Payload Orbit',data=data)
# Out:
# <AxesSubplot:xlabel='Payload Orbit', ylabel='Payload to Orbit (kg)'>

# %%
data["Failure Reason"].unique()
# Out:
# array(['Transtage failed to pressurize.',
#        'The Transtage disintegrated causing a launch failure.',
#        'A loss of thrust in the second stage means the rocket failed to achieve orbit.',
#        'A problem with the second stage protective skirt caused a lower then planned orbit.',
#        'Agena pressurization failure', 'Agena Failed to reach orbit',
#        'Combustion instability that had occurred in one of the Viking first stage engines.',
#        'Third stage turbopump malfunction.',
#        'The kickstage was off axis during its burn, resulting in a failure to achieve orbit.',
#        nan,
#        "One SRB failed to separate, retarding the booster's orbital velocity.",
#        "The Ariane 5 program's first launch failed because of a programming error. Range safety officers elected to destroy the rocket during the launch, according to the Ariane 5 Flight 501 failure report. Maiden flight of Ariane 5G",
#        'Payload fairing disintegrated at T+78 seconds leading to a loss of the launch vehicle.',
#        'malfunction of the first stage',
#        'Exploded 13 seconds after launch due to SRB failure.',
#        'Flight program, adapted to the Delta II, and not to the Delta III',
#        'Launch failed due to an anomaly on the second stage',
#        'malfunction of the second stage',
#        'first stage engine failure, rocket destroyed by range safety.',
#        'launcher exploded on the pad two days before the launch, killing 21 people',
#        'Common Booster Cores shutdown prematurely putting the payloads in a lower than planned orbit',
#        'Engine Fire During Launch', 'Engine Shutdown During Launch',
#        'Collision During Launch', 'Engine Failure During Flight',
#        'Vehicle Explosion During Flight',
#        'Vehicle Explosion Before Launch',
#        'anomaly occurred shortly after the planned second stage ignition, leading to a loss of the launch vehicle and its payload'],
#       dtype=object)

# %%
data["Failure Reason"].value_counts()
# Out:
# Collision During Launch                                                                                                                                                                                                              3
# first stage engine failure, rocket destroyed by range safety.                                                                                                                                                                        1
# The kickstage was off axis during its burn, resulting in a failure to achieve orbit.                                                                                                                                                 1
# Third stage turbopump malfunction.                                                                                                                                                                                                   1
# Engine Shutdown During Launch                                                                                                                                                                                                        1
# Agena Failed to reach orbit                                                                                                                                                                                                          1
# Engine Fire During Launch                                                                                                                                                                                                            1
# One SRB failed to separate, retarding the booster's orbital velocity.                                                                                                                                                                1
# Common Booster Cores shutdown prematurely putting the payloads in a lower than planned orbit                                                                                                                                         1
# The Transtage disintegrated causing a launch failure.                                                                                                                                                                                1
# anomaly occurred shortly after the planned second stage ignition, leading to a loss of the launch vehicle and its payload                                                                                                            1
# The Ariane 5 program's first launch failed because of a programming error. Range safety officers elected to destroy the rocket during the launch, according to the Ariane 5 Flight 501 failure report. Maiden flight of Ariane 5G    1
# Combustion instability that had occurred in one of the Viking first stage engines.                                                                                                                                                   1
# Engine Failure During Flight                                                                                                                                                                                                         1
# Payload fairing disintegrated at T+78 seconds leading to a loss of the launch vehicle.                                                                                                                                               1
# A problem with the second stage protective skirt caused a lower then planned orbit.                                                                                                                                                  1
# Agena pressurization failure                                                                                                                                                                                                         1
# malfunction of the second stage                                                                                                                                                                                                      1
# Flight program, adapted to the Delta II, and not to the Delta III                                                                                                                                                                    1
# A loss of thrust in the second stage means the rocket failed to achieve orbit.                                                                                                                                                       1
# Launch failed due to an anomaly on the second stage                                                                                                                                                                                  1
# Vehicle Explosion Before Launch                                                                                                                                                                                                      1
# launcher exploded on the pad two days before the launch, killing 21 people                                                                                                                                                           1
# Transtage failed to pressurize.                                                                                                                                                                                                      1
# Vehicle Explosion During Flight                                                                                                                                                                                                      1
# malfunction of the first stage                                                                                                                                                                                                       1
# Exploded 13 seconds after launch due to SRB failure.                                                                                                                                                                                 1
# Name: Failure Reason, dtype: int64

# %%
data
# Out:
#      Company Launch Date Launch Time  Temperature (° F)  Wind speed (MPH)  \
# 20         6        1964       15:00          70.441176          8.007353
# 19         6        1965       17:23          70.441176          8.007353
# 18         6        1967         NaN          56.000000         12.000000
# 17         6        1967       16:19          60.000000         15.000000
# 16         6        1972       15:30          64.000000         20.000000
# ..       ...         ...         ...                ...               ...
# 113        5        2020        2:19          48.000000          5.000000
# 114        5        2020       15:30          81.000000          8.000000
# 115        5        2020       14:06          72.000000          8.000000
# 116        5        2020       15:05          77.000000          9.000000
# 117        5        2020        4:50          55.000000         22.000000
#
#      Humidity (%)  Vehicle Type  Liftoff Thrust (kN)  Payload to Orbit (kg)  \
# 20      76.066176            11                 1936                   3100
# 19      76.066176            11                13642                  13100
# 18      75.000000            11                 2300                   3300
# 17      80.000000            11                 2300                   3300
# 16      46.000000            11                 2410                   4000
# ..            ...           ...                  ...                    ...
# 113     93.000000             9                 7607                  22800
# 114     54.000000             9                 7607                  22800
# 115     68.000000             9                 7607                  22800
# 116     74.000000             9                 7607                  22800
# 117     55.000000             9                 7607                  22800
#
#      Rocket Height (m)  Fairing Diameter (m)                     Payload Name  \
# 20                42.0                  3.00                      Transtage 1
# 19                42.0                  3.00                            LCS-2
# 18                45.0                  1.52                KH-8 Gambit no.05
# 17                45.0                  1.52                KH-8 Gambit no.06
# 16                50.0                  3.00                      KH-8 no. 35
# ..                 ...                   ...                              ...
# 113               70.0                  5.20                   Starlink V1 L2
# 114               70.0                  5.20  Crew Dragon Inflight Abort Test
# 115               70.0                  5.20                   Starlink V1 L3
# 116               70.0                  5.20                   Starlink V1 L4
# 117               70.0                  5.20                           CRS-20
#
#      Payload Type Payload Mass (kg)  Payload Orbit  Mission Status  \
# 20              3                 0              4               0
# 19              5               NaN              4               0
# 18              4              3000              7               0
# 17              4              3000              7               0
# 16              4              3000              4               0
# ..            ...               ...            ...             ...
# 113             0             15600              4               1
# 114             3              6350              8               1
# 115             0             15600              4               1
# 116             0             15600              4               1
# 117             7              2500              4               1
#
#                                         Failure Reason
# 20                     Transtage failed to pressurize.
# 19   The Transtage disintegrated causing a launch f...
# 18   A loss of thrust in the second stage means the...
# 17   A problem with the second stage protective ski...
# 16                        Agena pressurization failure
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
# [150 rows x 17 columns]

# %%
data=data.drop("Launch Time",axis=1)

# %%
data["Launch Date"].value_counts()
# Out:
# 2018    21
# 2017    18
# 2019    14
# 1999    12
# 2016    10
# 2015     8
# 2000     7
# 2001     7
# 2014     6
# 2002     5
# 2020     5
# 2008     4
# 1998     4
# 2012     3
# 2013     3
# 1996     2
# 2010     2
# 1997     2
# 2003     2
# 1967     2
# 1965     1
# 1980     1
# 2009     1
# 1995     1
# 2007     1
# 2006     1
# 1972     1
# 1994     1
# 1964     1
# 2004     1
# 1973     1
# 1993     1
# 1982     1
# Name: Launch Date, dtype: int64

# %%
data['Payload Type'].unique()
# Out:
# array([3, 5, 4, 0, 6, 2, 1, 8, 7])

# %%
data=data.drop('Payload Name',axis=1)

# %%
data=data.drop('Launch Date',axis=1)

# %%
data=data.drop('Payload Mass (kg)',axis=1)

# %%
data_status=data

# %%
data_status=data_status.drop('Failure Reason',axis=1)

# %%
data_status
# Out:
#      Company  Temperature (° F)  Wind speed (MPH)  Humidity (%)  Vehicle Type  \
# 20         6          70.441176          8.007353     76.066176            11
# 19         6          70.441176          8.007353     76.066176            11
# 18         6          56.000000         12.000000     75.000000            11
# 17         6          60.000000         15.000000     80.000000            11
# 16         6          64.000000         20.000000     46.000000            11
# ..       ...                ...               ...           ...           ...
# 113        5          48.000000          5.000000     93.000000             9
# 114        5          81.000000          8.000000     54.000000             9
# 115        5          72.000000          8.000000     68.000000             9
# 116        5          77.000000          9.000000     74.000000             9
# 117        5          55.000000         22.000000     55.000000             9
#
#      Liftoff Thrust (kN)  Payload to Orbit (kg)  Rocket Height (m)  \
# 20                  1936                   3100               42.0
# 19                 13642                  13100               42.0
# 18                  2300                   3300               45.0
# 17                  2300                   3300               45.0
# 16                  2410                   4000               50.0
# ..                   ...                    ...                ...
# 113                 7607                  22800               70.0
# 114                 7607                  22800               70.0
# 115                 7607                  22800               70.0
# 116                 7607                  22800               70.0
# 117                 7607                  22800               70.0
#
#      Fairing Diameter (m)  Payload Type  Payload Orbit  Mission Status
# 20                   3.00             3              4               0
# 19                   3.00             5              4               0
# 18                   1.52             4              7               0
# 17                   1.52             4              7               0
# 16                   3.00             4              4               0
# ..                    ...           ...            ...             ...
# 113                  5.20             0              4               1
# 114                  5.20             3              8               1
# 115                  5.20             0              4               1
# 116                  5.20             0              4               1
# 117                  5.20             7              4               1
#
# [150 rows x 12 columns]

# %%
data_status=data_status.dropna()

# %%
data_status=data_status.sample(frac=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
X=data_status.iloc[:,:12]

# %%
X=scaler.fit_transform(X)

# %%
X
# Out:
# array([[0.83333333, 0.26785714, 0.13043478, ..., 0.375     , 0.1       ,
#         1.        ],
#        [0.83333333, 0.55357143, 0.56521739, ..., 0.375     , 0.7       ,
#         1.        ],
#        [0.83333333, 0.59716387, 0.34814578, ..., 0.375     , 0.4       ,
#         0.        ],
#        ...,
#        [0.16666667, 0.89285714, 0.39130435, ..., 0.375     , 0.2       ,
#         1.        ],
#        [0.83333333, 0.75      , 0.34782609, ..., 0.        , 0.1       ,
#         1.        ],
#        [0.83333333, 0.92857143, 0.56521739, ..., 0.        , 0.1       ,
#         1.        ]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
y=data_status.iloc[:,11:]
y
# Out:
#      Mission Status
# 80                1
# 37                1
# 4                 0
# 113               1
# 50                1
# ..              ...
# 43                1
# 42                1
# 142               1
# 87                1
# 58                1
#
# [146 rows x 1 columns]

# %%
y=scaler.fit_transform(y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
X.shape
X_train=X[:120,:]

# %%
X_train
# Out:
# array([[0.83333333, 0.26785714, 0.13043478, ..., 0.375     , 0.1       ,
#         1.        ],
#        [0.83333333, 0.55357143, 0.56521739, ..., 0.375     , 0.7       ,
#         1.        ],
#        [0.83333333, 0.59716387, 0.34814578, ..., 0.375     , 0.4       ,
#         0.        ],
#        ...,
#        [0.83333333, 0.75      , 0.26086957, ..., 0.        , 0.1       ,
#         1.        ],
#        [0.83333333, 0.71428571, 0.52173913, ..., 0.        , 0.1       ,
#         1.        ],
#        [0.83333333, 0.67857143, 0.26086957, ..., 0.        , 0.1       ,
#         1.        ]])

# %%
y_train=y[:120,:]

# %%
logreg = LogisticRegression()

# %%
y_train.shape
# Out:
# (120, 1)

# %%
logreg.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
X_test=X[120:,:]
X_test
# Out:
# array([[0.83333333, 0.25      , 0.        , 0.73015873, 0.54545455,
#         0.24657412, 0.0704825 , 0.93207547, 0.95454545, 0.375     ,
#         1.        , 1.        ],
#        [0.83333333, 0.67857143, 0.30434783, 0.9047619 , 0.81818182,
#         0.32318918, 0.35351624, 0.96226415, 0.95454545, 0.875     ,
#         0.4       , 1.        ],
#        [0.83333333, 0.5       , 0.13043478, 1.        , 0.54545455,
#         0.24657412, 0.20135604, 0.93207547, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.83333333, 0.59716387, 0.34814578, 0.62009804, 0.36363636,
#         0.        , 0.00141911, 0.06132075, 0.11363636, 1.        ,
#         0.4       , 1.        ],
#        [0.83333333, 0.57142857, 0.39130435, 0.22222222, 0.81818182,
#         0.32318918, 0.35351624, 0.96226415, 0.95454545, 0.375     ,
#         0.6       , 1.        ],
#        [1.        , 0.59716387, 0.34814578, 0.62009804, 1.        ,
#         0.59169781, 0.20056764, 0.43396226, 0.45454545, 0.625     ,
#         0.4       , 0.        ],
#        [0.83333333, 0.28571429, 0.        , 0.77777778, 0.72727273,
#         0.28746218, 0.12488174, 0.96226415, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.16666667, 0.71428571, 0.52173913, 0.52380952, 0.27272727,
#         0.14095035, 0.02269   , 0.36037736, 0.43181818, 0.        ,
#         0.1       , 1.        ],
#        [0.83333333, 0.59716387, 0.34814578, 0.62009804, 0.36363636,
#         0.        , 0.00141911, 0.06132075, 0.11363636, 0.75      ,
#         0.4       , 0.        ],
#        [1.        , 0.94642857, 0.52173913, 0.52380952, 1.        ,
#         0.59169781, 0.20056764, 0.43396226, 0.45454545, 0.375     ,
#         0.4       , 0.        ],
#        [0.83333333, 0.80357143, 0.7826087 , 0.52380952, 0.63636364,
#         0.28746218, 0.12488174, 0.96226415, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.83333333, 1.        , 0.43478261, 0.07936508, 0.54545455,
#         0.24657412, 0.20135604, 0.93207547, 0.95454545, 0.875     ,
#         0.4       , 0.        ],
#        [0.83333333, 0.82142857, 0.34782609, 0.80952381, 0.90909091,
#         0.28746218, 0.12488174, 0.96226415, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.83333333, 0.64285714, 0.56521739, 0.38095238, 0.90909091,
#         0.28746218, 0.35351624, 0.96226415, 0.95454545, 0.875     ,
#         0.4       , 1.        ],
#        [0.83333333, 0.46428571, 0.2173913 , 0.80952381, 0.81818182,
#         0.32318918, 0.12488174, 0.96226415, 0.95454545, 0.375     ,
#         0.1       , 1.        ],
#        [0.83333333, 0.57142857, 0.39130435, 0.6031746 , 0.72727273,
#         0.28746218, 0.12488174, 0.96226415, 0.95454545, 0.375     ,
#         0.3       , 1.        ],
#        [0.83333333, 0.73214286, 0.30434783, 0.80952381, 0.45454545,
#         0.20452928, 0.15878272, 0.67735849, 0.95454545, 1.        ,
#         0.4       , 1.        ],
#        [0.83333333, 0.30357143, 0.        , 0.9047619 , 0.72727273,
#         0.28746218, 0.12488174, 0.96226415, 0.95454545, 0.375     ,
#         0.1       , 1.        ],
#        [0.16666667, 0.44642857, 0.2173913 , 0.73015873, 1.        ,
#         0.40345257, 0.44134342, 1.        , 0.93181818, 0.625     ,
#         0.1       , 0.        ],
#        [0.16666667, 0.91071429, 0.        , 0.33333333, 0.09090909,
#         0.11910482, 0.04287291, 0.3754717 , 0.45454545, 0.        ,
#         0.4       , 1.        ],
#        [0.83333333, 0.25      , 0.26086957, 0.68253968, 0.81818182,
#         0.32318918, 0.35351624, 0.96226415, 0.95454545, 0.        ,
#         0.9       , 1.        ],
#        [0.83333333, 0.67857143, 0.13043478, 0.84126984, 0.54545455,
#         0.24657412, 0.0704825 , 0.93207547, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.83333333, 0.82142857, 0.52173913, 0.66666667, 0.54545455,
#         0.24657412, 0.0704825 , 0.93207547, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.16666667, 0.89285714, 0.39130435, 0.44444444, 1.        ,
#         0.09743727, 0.00873541, 0.36037736, 0.43181818, 0.375     ,
#         0.2       , 1.        ],
#        [0.83333333, 0.75      , 0.34782609, 0.50793651, 0.81818182,
#         0.32318918, 0.12488174, 0.96226415, 0.95454545, 0.        ,
#         0.1       , 1.        ],
#        [0.83333333, 0.92857143, 0.56521739, 0.52380952, 0.90909091,
#         0.28746218, 0.12488174, 0.96226415, 0.95454545, 0.        ,
#         0.1       , 1.        ]])

# %%
y_test=y[120:,:]

# %%
y_pred = logreg.predict(X_test)

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 1.00

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[ 5  0]
#  [ 0 21]]

# %%
from sklearn import svm

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVC()

# %%
clf.predict(X_test)
# Out:
# array([1., 1., 1., 1., 1., 0., 1., 1., 0., 0., 1., 0., 1., 1., 1., 1., 1.,
#        1., 0., 1., 1., 1., 1., 1., 1., 1.])

# %%
y_test
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
sns.pairplot(data=data)
